# %%
from flask import Flask, send_file

# %%
app = Flask(__name__)
# app accessible locally at http://127.0.0.1:5000/

# get landsat products available at location
@app.route('/landsatFramesLatLon=<string:latlon>/', methods=['GET'])
def landsatFramesLatLon(latlon):
    lat,lon = latlon.split(',')
    frameid = 00000000
    return frameid

# check if a landsat product is in the archive
@app.route('/frameInDB=<string:frameid>/', methods=['GET'])
def frameInDB(frameid):
    return frameid

# download landsat products only if not in archive

# crop and normalize landsat product in archive based on lat lon and product id

# compose landsat images into layout for email

# return landsat cropped image 
@app.route('/returnImage/', methods=['GET'])
def returnImage():
    return send_file('pngs/2023_05_10.png', mimetype='image/png')

# send satellite pass email for lat lon

# send satellite pass and image email for lat lon

# get landsat cropped image (full process)

# add a new email subscriber

# add a new location of interest to email subscriber (require key)

# remove new location of interest for email subscriber (require key)

# show locations of interest for an email subscriber (require key) do not hint if user exists!

# show notifications that have been sent to user (require key)

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/May/2023 18:18:11] "GET /returnImage/ HTTP/1.1" 200 -
